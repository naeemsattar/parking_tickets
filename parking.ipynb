# %%
import pandas as pd

# %%
import dask

# %%
import dask.dataframe as dd

# %%
# Reading only 1 cvs file as Data is huge. 
#this is the file "Parking_Violations_Issued_-_Fiscal_Year_2017.csv"
ddf = dd.read_csv("./Parking_Violations_Issued_-_Fiscal_Year_2017.csv" ,
                  dtype='unicode'
 )

# %%
#checking if the data is fetched
try:
    ddf.head()
except:
    print("error")

# %%
ddf.head().T
# Out:
#                                                               0  \
# Summons Number                                       5092469481
# Plate ID                                                GZH7067
# Registration State                                           NY
# Plate Type                                                  PAS
# Issue Date                                           07/10/2016
# Violation Code                                                7
# Vehicle Body Type                                          SUBN
# Vehicle Make                                              TOYOT
# Issuing Agency                                                V
# Street Code1                                                  0
# Street Code2                                                  0
# Street Code3                                                  0
# Vehicle Expiration Date                                       0
# Violation Location                                          NaN
# Violation Precinct                                            0
# Issuer Precinct                                               0
# Issuer Code                                                   0
# Issuer Command                                              NaN
# Issuer Squad                                                NaN
# Violation Time                                            0143A
# Time First Observed                                         NaN
# Violation County                                             BX
# Violation In Front Of Or Opposite                           NaN
# House Number                                                NaN
# Street Name                                ALLERTON AVE (W/B) @
# Intersecting Street                                  BARNES AVE
# Date First Observed                                           0
# Law Section                                                1111
# Sub Division                                                  D
# Violation Legal Code                                          T
# Days Parking In Effect                                      NaN
# From Hours In Effect                                        NaN
# To Hours In Effect                                          NaN
# Vehicle Color                                                GY
# Unregistered Vehicle?                                       NaN
# Vehicle Year                                               2001
# Meter Number                                                NaN
# Feet From Curb                                                0
# Violation Post Code                                         NaN
# Violation Description              FAILURE TO STOP AT RED LIGHT
# No Standing or Stopping Violation                           NaN
# Hydrant Violation                                           NaN
# Double Parking Violation                                    NaN
#
#                                                               1  \
# Summons Number                                       5092451658
# Plate ID                                                GZH7067
# Registration State                                           NY
# Plate Type                                                  PAS
# Issue Date                                           07/08/2016
# Violation Code                                                7
# Vehicle Body Type                                          SUBN
# Vehicle Make                                              TOYOT
# Issuing Agency                                                V
# Street Code1                                                  0
# Street Code2                                                  0
# Street Code3                                                  0
# Vehicle Expiration Date                                       0
# Violation Location                                          NaN
# Violation Precinct                                            0
# Issuer Precinct                                               0
# Issuer Code                                                   0
# Issuer Command                                              NaN
# Issuer Squad                                                NaN
# Violation Time                                            0400P
# Time First Observed                                         NaN
# Violation County                                             BX
# Violation In Front Of Or Opposite                           NaN
# House Number                                                NaN
# Street Name                                ALLERTON AVE (W/B) @
# Intersecting Street                                  BARNES AVE
# Date First Observed                                           0
# Law Section                                                1111
# Sub Division                                                  D
# Violation Legal Code                                          T
# Days Parking In Effect                                      NaN
# From Hours In Effect                                        NaN
# To Hours In Effect                                          NaN
# Vehicle Color                                                GY
# Unregistered Vehicle?                                       NaN
# Vehicle Year                                               2001
# Meter Number                                                NaN
# Feet From Curb                                                0
# Violation Post Code                                         NaN
# Violation Description              FAILURE TO STOP AT RED LIGHT
# No Standing or Stopping Violation                           NaN
# Hydrant Violation                                           NaN
# Double Parking Violation                                    NaN
#
#                                                       2  \
# Summons Number                               4006265037
# Plate ID                                        FZX9232
# Registration State                                   NY
# Plate Type                                          PAS
# Issue Date                                   08/23/2016
# Violation Code                                        5
# Vehicle Body Type                                  SUBN
# Vehicle Make                                       FORD
# Issuing Agency                                        V
# Street Code1                                          0
# Street Code2                                          0
# Street Code3                                          0
# Vehicle Expiration Date                               0
# Violation Location                                  NaN
# Violation Precinct                                    0
# Issuer Precinct                                       0
# Issuer Code                                           0
# Issuer Command                                      NaN
# Issuer Squad                                        NaN
# Violation Time                                    0233P
# Time First Observed                                 NaN
# Violation County                                     BX
# Violation In Front Of Or Opposite                   NaN
# House Number                                        NaN
# Street Name                        SB WEBSTER AVE @ E 1
# Intersecting Street                             94TH ST
# Date First Observed                                   0
# Law Section                                        1111
# Sub Division                                          C
# Violation Legal Code                                  T
# Days Parking In Effect                              NaN
# From Hours In Effect                                NaN
# To Hours In Effect                                  NaN
# Vehicle Color                                        BK
# Unregistered Vehicle?                               NaN
# Vehicle Year                                       2004
# Meter Number                                        NaN
# Feet From Curb                                        0
# Violation Post Code                                 NaN
# Violation Description                BUS LANE VIOLATION
# No Standing or Stopping Violation                   NaN
# Hydrant Violation                                   NaN
# Double Parking Violation                            NaN
#
#                                                        3  \
# Summons Number                                8478629828
# Plate ID                                         66623ME
# Registration State                                    NY
# Plate Type                                           COM
# Issue Date                                    06/14/2017
# Violation Code                                        47
# Vehicle Body Type                                   REFG
# Vehicle Make                                       MITSU
# Issuing Agency                                         T
# Street Code1                                       10610
# Street Code2                                       34330
# Street Code3                                       34350
# Vehicle Expiration Date                         20180630
# Violation Location                                  0014
# Violation Precinct                                    14
# Issuer Precinct                                       14
# Issuer Code                                       359594
# Issuer Command                                      T102
# Issuer Squad                                           J
# Violation Time                                     1120A
# Time First Observed                                  NaN
# Violation County                                      NY
# Violation In Front Of Or Opposite                      O
# House Number                                         330
# Street Name                                      7th Ave
# Intersecting Street                                  NaN
# Date First Observed                                    0
# Law Section                                          408
# Sub Division                                          l2
# Violation Legal Code                                 NaN
# Days Parking In Effect                                 Y
# From Hours In Effect                               0700A
# To Hours In Effect                                 0700P
# Vehicle Color                                         WH
# Unregistered Vehicle?                                NaN
# Vehicle Year                                        2007
# Meter Number                                         NaN
# Feet From Curb                                         0
# Violation Post Code                                   04
# Violation Description              47-Double PKG-Midtown
# No Standing or Stopping Violation                    NaN
# Hydrant Violation                                    NaN
# Double Parking Violation                             NaN
#
#                                                                4
# Summons Number                                        7868300310
# Plate ID                                                 37033JV
# Registration State                                            NY
# Plate Type                                                   COM
# Issue Date                                            11/21/2016
# Violation Code                                                69
# Vehicle Body Type                                           DELV
# Vehicle Make                                               INTER
# Issuing Agency                                                 T
# Street Code1                                               10510
# Street Code2                                               34310
# Street Code3                                               34330
# Vehicle Expiration Date                                 20170228
# Violation Location                                          0013
# Violation Precinct                                            13
# Issuer Precinct                                               13
# Issuer Code                                               364832
# Issuer Command                                              T102
# Issuer Squad                                                   M
# Violation Time                                             0555P
# Time First Observed                                          NaN
# Violation County                                              NY
# Violation In Front Of Or Opposite                              F
# House Number                                                 799
# Street Name                                              6th Ave
# Intersecting Street                                          NaN
# Date First Observed                                            0
# Law Section                                                  408
# Sub Division                                                  h1
# Violation Legal Code                                         NaN
# Days Parking In Effect                                         Y
# From Hours In Effect                                       0700A
# To Hours In Effect                                         0700P
# Vehicle Color                                              WHITE
# Unregistered Vehicle?                                        NaN
# Vehicle Year                                                2007
# Meter Number                                                 NaN
# Feet From Curb                                                 0
# Violation Post Code                                         31 6
# Violation Description              69-Failure to Disp Muni Recpt
# No Standing or Stopping Violation                            NaN
# Hydrant Violation                                            NaN
# Double Parking Violation                                     NaN

# %%
ddf.tail().T
# Out:
#                                           210390           210391      210392  \
# Summons Number                        1415891400       1384716543  1413536554
# Plate ID                                 HGK6453          GRA6240      RC8S28
# Registration State                            NJ               NY          PA
# Plate Type                                   PAS              PAS         PAS
# Issue Date                            11/02/2068       07/12/2069  08/14/2069
# Violation Code                                21               20          46
# Vehicle Body Type                            SDN             SUBN        SUBN
# Vehicle Make                               HONDA            TOYOT         NaN
# Issuing Agency                                 S                X           P
# Street Code1                               17380            93830       37980
# Street Code2                                5780            64830       14080
# Street Code3                                5880            23330       14130
# Vehicle Expiration Date                        0         20161001    20160930
# Violation Location                          0068             0071        0069
# Violation Precinct                            68               71          69
# Issuer Precinct                                0              976          69
# Issuer Code                               582845           100519      949860
# Issuer Command                              KS10             0976        0069
# Issuer Squad                                0000             0000        0000
# Violation Time                             1207P            0750A       1150A
# Time First Observed                          NaN              NaN         NaN
# Violation County                               K                K           K
# Violation In Front Of Or Opposite              F                F           F
# House Number                                 715              444        1285
# Street Name                        BAY RIDGE AVE  WINTHROP STREET     E 94 ST
# Intersecting Street                          NaN              NaN         NaN
# Date First Observed                            0                0           0
# Law Section                                  408              408         408
# Sub Division                                  D1                D          J2
# Violation Legal Code                         NaN              NaN         NaN
# Days Parking In Effect                   BBYBBBB          BBBBBBB     BBBBBBB
# From Hours In Effect                       1130A              ALL         ALL
# To Hours In Effect                         0100P              ALL         ALL
# Vehicle Color                              BLACK             GRAY         RED
# Unregistered Vehicle?                          0                0           0
# Vehicle Year                                   0             2007           0
# Meter Number                                   -                -           -
# Feet From Curb                                 0                0           0
# Violation Post Code                          NaN              NaN         NaN
# Violation Description                        NaN              NaN         NaN
# No Standing or Stopping Violation            NaN              NaN         NaN
# Hydrant Violation                            NaN              NaN         NaN
# Double Parking Violation                     NaN              NaN         NaN
#
#                                        210393      210394
# Summons Number                     1415514203  1415995370
# Plate ID                              HGU9544     GPP1608
# Registration State                         NY          NY
# Plate Type                                PAS         PAS
# Issue Date                         11/15/2069  11/19/2069
# Violation Code                             40          21
# Vehicle Body Type                        SUBN         SDN
# Vehicle Make                             JEEP       TOYOT
# Issuing Agency                              P           S
# Street Code1                                0       38080
# Street Code2                             5530       40230
# Street Code3                                0       77740
# Vehicle Expiration Date              20180624    20180605
# Violation Location                       0069        0069
# Violation Precinct                         69          69
# Issuer Precinct                            69           0
# Issuer Code                            935065      980319
# Issuer Command                           0069        KS18
# Issuer Squad                             0000        0000
# Violation Time                          0319A       0843A
# Time First Observed                       NaN         NaN
# Violation County                            K           K
# Violation In Front Of Or Opposite           F           F
# House Number                               37        1018
# Street Name                        PAERDERGAT     E 96 ST
# Intersecting Street                      4 ST         NaN
# Date First Observed                         0           0
# Law Section                               408         408
# Sub Division                               E2          D1
# Violation Legal Code                      NaN         NaN
# Days Parking In Effect                BBBBBBB     BBBYBBB
# From Hours In Effect                      ALL       0830A
# To Hours In Effect                        ALL       1000A
# Vehicle Color                           BROWN        GRAY
# Unregistered Vehicle?                       0           0
# Vehicle Year                             2011        2011
# Meter Number                                -           -
# Feet From Curb                              0           0
# Violation Post Code                       NaN         NaN
# Violation Description                     NaN         NaN
# No Standing or Stopping Violation         NaN         NaN
# Hydrant Violation                         NaN         NaN
# Double Parking Violation                  NaN         NaN

# %%
# Finding the missing values
ddf.isna().sum().compute()
# Out:
# Summons Number                              0
# Plate ID                                  728
# Registration State                          0
# Plate Type                                  0
# Issue Date                                  0
# Violation Code                              0
# Vehicle Body Type                       42711
# Vehicle Make                            73050
# Issuing Agency                              0
# Street Code1                                0
# Street Code2                                0
# Street Code3                                0
# Vehicle Expiration Date                     0
# Violation Location                    2072400
# Violation Precinct                          0
# Issuer Precinct                             0
# Issuer Code                                 0
# Issuer Command                        2062645
# Issuer Squad                          2063541
# Violation Time                             63
# Time First Observed                   9962281
# Violation County                        39547
# Violation In Front Of Or Opposite     2161235
# House Number                          2288618
# Street Name                              4009
# Intersecting Street                   7435473
# Date First Observed                         0
# Law Section                                 0
# Sub Division                              773
# Violation Legal Code                  8740321
# Days Parking In Effect                2712416
# From Hours In Effect                  5450946
# To Hours In Effect                    5450943
# Vehicle Color                          152342
# Unregistered Vehicle?                 9675432
# Vehicle Year                                0
# Meter Number                          9017555
# Feet From Curb                              0
# Violation Post Code                   3190187
# Violation Description                 1127470
# No Standing or Stopping Violation    10803028
# Hydrant Violation                    10803028
# Double Parking Violation             10803028
# dtype: int64

# %%
ddf.compute().shape
#Below we can see the shape. 

# on the above cell we can see the missing values. The following columns are have no data.
# We can straight forward drop these columns
# No Standing or Stopping Violation    10803028
# Hydrant Violation                    10803028
# Double Parking Violation             10803028
# Out:
# (10803028, 43)

# %%
# Droping following columns
# No Standing or Stopping Violation    10803028
# Hydrant Violation                    10803028
# Double Parking Violation             10803028

# %%
# assign results to new dataframe ddf1
ddf1 = ddf.drop(['No Standing or Stopping Violation','Hydrant Violation','Double Parking Violation'],axis=1)

# %%
ddf1.columns
# following columns successfuly dropped
# No Standing or Stopping Violation    10803028
# Hydrant Violation                    10803028
# Double Parking Violation             10803028
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description'],
#       dtype='object')

# %%
# Column "Plate ID" has 728 missing values. Let's inspect the these records
ddf1[ddf1['Plate ID'].isna()].compute()

# "Violation Description" shows that why the column "Plate ID" is missing. 
# So we can not drop these records.
# Out:
#        Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 11889      8240027763      NaN                 NY        PAS  01/14/2017
# 28537      8233020280      NaN                 NY        PAS  11/21/2016
# 35569      8581550060      NaN                 NY        PAS  06/08/2017
# 36497      7802856115      NaN                 NY        MOT  08/25/2016
# 47093      7468294598      NaN                 NY        PAS  09/07/2016
# ...               ...      ...                ...        ...         ...
# 194007     8236026978      NaN                 NY        PAS  06/30/2016
# 194008     8236026966      NaN                 NY        PAS  06/30/2016
# 194009     8236026954      NaN                 NY        PAS  06/30/2016
# 194010     8236026942      NaN                 NY        PAS  06/30/2016
# 194011     8236026929      NaN                 NY        PAS  06/30/2016
#
#        Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 11889              71              4DSD          BMW              T
# 28537              71              2DSD        VOLKS              T
# 35569              74              4DSD        OLDSM              T
# 36497              74               MCC        VESPA              T
# 47093              74              4DSD        HYUND              T
# ...               ...               ...          ...            ...
# 194007             74              2DSD        MITSU              T
# 194008             74              SUBN        ISUZU              T
# 194009             74              SUBN          BMW              T
# 194010             74              SUBN        SUBAR              T
# 194011             74              4DSD        HYUND              T
#
#        Street Code1  ... Days Parking In Effect     From Hours In Effect  \
# 11889         66790  ...                    YYYYYYY                  NaN
# 28537         53790  ...                    YYYYYYY                  NaN
# 35569         20220  ...                    YYYYYYY                  NaN
# 36497          9990  ...                        NaN                  NaN
# 47093         51090  ...                        NaN                  NaN
# ...             ...  ...                        ...                  ...
# 194007        65325  ...                        NaN                  NaN
# 194008        53790  ...                        NaN                  NaN
# 194009        53790  ...                        NaN                  NaN
# 194010        53790  ...                        NaN                  NaN
# 194011        65325  ...                        NaN                  NaN
#
#        To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year  \
# 11889                 NaN         SILVE                   NaN         1999
# 28537                 NaN         SILVE                   NaN            0
# 35569                 NaN          BLUE                   NaN         2002
# 36497                 NaN          BLUE                   NaN            0
# 47093                 NaN         BLACK                   NaN            0
# ...                   ...           ...                   ...          ...
# 194007                NaN         SILVE                   NaN            0
# 194008                NaN         BROWN                   NaN            0
# 194009                NaN         OTHER                   NaN            0
# 194010                NaN          BLUE                   NaN            0
# 194011                NaN          BLUE                   NaN            0
#
#        Meter Number Feet From Curb Violation Post Code  \
# 11889           NaN              0                  17
# 28537           NaN              0                13 4
# 35569           NaN              0                   A
# 36497           NaN              0                01 6
# 47093           NaN              0                19 4
# ...             ...            ...                 ...
# 194007          NaN              0                14 4
# 194008          NaN              0                14 4
# 194009          NaN              0                14 4
# 194010          NaN              0                14 4
# 194011          NaN              0                14 4
#
#                  Violation Description
# 11889   71A-Insp Sticker Expired (NYS)
# 28537   71A-Insp Sticker Expired (NYS)
# 35569         74-Missing Display Plate
# 36497         74-Missing Display Plate
# 47093         74-Missing Display Plate
# ...                                ...
# 194007        74-Missing Display Plate
# 194008        74-Missing Display Plate
# 194009        74-Missing Display Plate
# 194010        74-Missing Display Plate
# 194011        74-Missing Display Plate
#
# [728 rows x 40 columns]
